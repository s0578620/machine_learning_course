# %%
import pandas as pd

df = pd.read_csv("./classification.csv")
df.head()
# Out:
#          age   interest  success
# 0  23.657801  18.859917      0.0
# 1  22.573729  17.969223      0.0
# 2  32.553424  29.463651      0.0
# 3   6.718035  25.704665      1.0
# 4  14.401919  16.770856      0.0

# %%
from sklearn.model_selection import train_test_split

X = df[["age", "interest"]].values
y = df["success"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0, test_size = 0.25)

# %%
from sklearn.preprocessing import StandardScaler    # Maßstab anpassen (Skala, siehe unten)

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.xlabel("Alter")
plt.ylabel("Interesse")
plt.show()

# %% [markdown]
# ### Logistische Regression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)

print(model.score(X_test, y_test))  # % angabe der Voraussage

y_predicted = model.predict(X_test)
# Out:
# 0.88

# %%
# %matplotlib inline  # echte daten
import matplotlib.pyplot as plt

plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test)
plt.xlabel("Alter")
plt.ylabel("Interesse")
plt.show()
# Out:
# UsageError: unrecognized arguments: # echte daten

# %%
# %matplotlib inline  # vorhergesagte daten
import matplotlib.pyplot as plt

plt.scatter(X_test[:, 0], X_test[:, 1], c=y_predicted)
plt.xlabel("Alter")
plt.ylabel("Interesse")
plt.show()
